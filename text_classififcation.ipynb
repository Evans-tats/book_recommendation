# %%
import pandas as pd
books = pd.read_csv("./books_cleaned.csv")

# %%
books["categories"].value_counts().head(7)
# Out:
# categories
# Fiction                      2111
# Juvenile Fiction              390
# Biography & Autobiography     311
# History                       207
# Literary Criticism            124
# Religion                      117
# Philosophy                    117
# Name: count, dtype: int64

# %%
category_mapping = {'Fiction' : "Fiction",
 'Juvenile Fiction': "Children's Fiction",
 'Biography & Autobiography': "Nonfiction",
 'History': "Nonfiction",
 'Literary Criticism': "Nonfiction",
 'Philosophy': "Nonfiction",
 'Religion': "Nonfiction",
 'Comics & Graphic Novels': "Fiction",
 'Drama': "Fiction",
 'Juvenile Nonfiction': "Children's Nonfiction",
 'Science': "Nonfiction",
 'Poetry': "Fiction"}

books["simple_categories"] = books["categories"].map(category_mapping)

# %%
books.head(5)
# Out:
#           isbn13      isbn10                title  \
# 0  9780002005883  0002005883               Gilead
# 1  9780002261982  0002261987         Spider's Web
# 2  9780006178736  0006178731       Rage of angels
# 3  9780006280897  0006280897       The Four Loves
# 4  9780006280934  0006280935  The Problem of Pain
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2                   Sidney Sheldon                        Fiction
# 3              Clive Staples Lewis                 Christian life
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=FKo2T...
# 3  http://books.google.com/books/content?id=XhQ5X...
# 4  http://books.google.com/books/content?id=Kk-uV...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3  Lewis' work on the nature of love divides love...          2002.0
# 4  "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
#
#    average_rating  num_pages  ratings_count    title_and_subtitle  \
# 0            3.85      247.0          361.0                Gilead
# 1            3.83      241.0         5164.0  Spider's Web:A Novel
# 2            3.93      512.0        29532.0        Rage of angels
# 3            4.15      170.0        33684.0        The Four Loves
# 4            4.09      176.0        37569.0   The Problem of Pain
#
#                                   tagged description simple_categories
# 0  9780002005883:A NOVEL THAT READERS and critics...           Fiction
# 1  9780002261982:A new 'Christie for Christmas' -...               NaN
# 2  9780006178736:A memorable, mesmerizing heroine...           Fiction
# 3  9780006280897:Lewis' work on the nature of lov...               NaN
# 4  9780006280934:"In The Problem of Pain, C.S. Le...               NaN

# %%
books[~(books["simple_categories"].isna())]
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 2     9780006178736  0006178731             Rage of angels
# 8     9780006482079  0006482074        Warhost of Vastmark
# 30    9780006646006  000664600X         Ocean Star Express
# 46    9780007121014  0007121016         Taken at the Flood
# ...             ...         ...                        ...
# 5178  9781933648279  1933648279  Night Has a Thousand Eyes
# 5188  9784770028969  4770028962         Coin Locker Babies
# 5189  9788122200850  8122200850           Cry, the Peacock
# 5195  9788185300535  8185300534                  I Am that
# 5196  9789027712059  9027712050   The Berlin Phenomenology
#
#                                            authors        categories  \
# 0                               Marilynne Robinson           Fiction
# 2                                   Sidney Sheldon           Fiction
# 8                                      Janny Wurts           Fiction
# 30                        Mark Haddon;Peter Sutton  Juvenile Fiction
# 46                                 Agatha Christie           Fiction
# ...                                            ...               ...
# 5178                              Cornell Woolrich           Fiction
# 5188                                           村上龍           Fiction
# 5189                                   Anita Desai           Fiction
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit        Philosophy
# 5196                 Georg Wilhelm Friedrich Hegel           History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 8     http://books.google.com/books/content?id=uOL0f...
# 30    http://books.google.com/books/content?id=I2QZA...
# 46    http://books.google.com/books/content?id=3gWlx...
# ...                                                 ...
# 5178  http://books.google.com/books/content?id=3Gk6s...
# 5188  http://books.google.com/books/content?id=87DJw...
# 5189  http://books.google.com/books/content?id=_QKwV...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 8     Tricked once more by his wily half-brother, Ly...          1995.0
# 30    Joe and his parents are enjoying a summer holi...          2002.0
# 46    A Few Weeks After Marrying An Attractive Young...          2002.0
# ...                                                 ...             ...
# 5178  "Cornell Woolrich's novels define the essence ...          2007.0
# 5188  Rescued from the lockers in which they were le...          2002.0
# 5189  This book is the story of a young girl obsesse...          1980.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 2               3.93      512.0        29532.0
# 8               4.03      522.0         2966.0
# 30              3.50       32.0            1.0
# 46              3.71      352.0         8852.0
# ...              ...        ...            ...
# 5178            3.77      344.0          680.0
# 5188            3.75      393.0         5560.0
# 5189            3.22      218.0          134.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                  title_and_subtitle  \
# 0                                            Gilead
# 2                                    Rage of angels
# 8                               Warhost of Vastmark
# 30                               Ocean Star Express
# 46                               Taken at the Flood
# ...                                             ...
# 5178                      Night Has a Thousand Eyes
# 5188                             Coin Locker Babies
# 5189                               Cry, the Peacock
# 5195  I Am that:Talks with Sri Nisargadatta Maharaj
# 5196                       The Berlin Phenomenology
#
#                                      tagged description   simple_categories
# 0     9780002005883:A NOVEL THAT READERS and critics...             Fiction
# 2     9780006178736:A memorable, mesmerizing heroine...             Fiction
# 8     9780006482079:Tricked once more by his wily ha...             Fiction
# 30    9780006646006:Joe and his parents are enjoying...  Children's Fiction
# 46    9780007121014:A Few Weeks After Marrying An At...             Fiction
# ...                                                 ...                 ...
# 5178  9781933648279:"Cornell Woolrich's novels defin...             Fiction
# 5188  9784770028969:Rescued from the lockers in whic...             Fiction
# 5189  9788122200850:This book is the story of a youn...             Fiction
# 5195  9788185300535:This collection of the timeless ...          Nonfiction
# 5196  9789027712059:Since the three volume edition o...          Nonfiction
#
# [3743 rows x 14 columns]

# %%
categories = ["fiction", "non_fiction"]
# Use a pipeline as a high-level helper

from transformers import pipeline

pipe = pipeline("zero-shot-classification",
                model="facebook/bart-large-mnli",
                device = "cpu")
# Out:
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[0]

# %%
pipe(sequence,categories)
# Out:
# {'sequence': 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.',
#  'labels': ['fiction', 'non_fiction'],
#  'scores': [0.8509016633033752, 0.14909830689430237]}

# %%
import numpy as np
max_index = np.argmax(pipe(sequence,categories)["scores"])
max_label = pipe(sequence,categories)["labels"][max_index]
max_label
# Out:
# 'fiction'

# %%
def generate_prediction(
        sequence,
        categories
):
    """
    Generate a prediction for the given sequence and categories.
    
    Args:
        sequence (str): The text to classify.
        categories (list): The list of categories to classify against.
        
    Returns:
        str: The predicted category.
    """
    prediction = pipe(sequence, categories)
    max_index = np.argmax(prediction["scores"])
    max_label = prediction["labels"][max_index]
    return max_label

# %%
from tqdm import tqdm

actual_cats = []
predicted_cats = []

for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_prediction(sequence, categories)]
    actual_cats +=["fiction"]
# Out:
#   1%|▏         | 4/300 [00:15<18:54,  3.83s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 8
#       6 for i in tqdm(range(0, 300)):
#       7     sequence = books.loc[books["simple_categories"] == "Fiction", "description"].reset_index(drop=True)[i]
# ----> 8     predicted_cats += [generate_prediction(sequence, categories)]
#       9     actual_cats +=["fiction"]
#
# Cell In[31], line 15, in generate_prediction(sequence, categories)
#       1 def generate_prediction(
#       2         sequence,
#       3         categories
#       4 ):
#       5     """
#       6     Generate a prediction for the given sequence and categories.
#       7
#    (...)
#      13         str: The predicted category.
#      14     """
# ---> 15     prediction = pipe(sequence, categories)
#      16     max_index = np.argmax(prediction["scores"])
#      17     max_label = prediction["labels"][max_index]
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/zero_shot_classification.py:204, in ZeroShotClassificationPipeline.__call__(self, sequences, *args, **kwargs)
#     201 else:
#     202     raise ValueError(f"Unable to understand extra arguments {args}")
# --> 204 return super().__call__(sequences, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1456, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1454     return self.iterate(inputs, preprocess_params, forward_params, postprocess_params)
#    1455 elif self.framework == "pt" and isinstance(self, ChunkPipeline):
# -> 1456     return next(
#    1457         iter(
#    1458             self.get_iterator(
#    1459                 [inputs], num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1460             )
#    1461         )
#    1462     )
#    1463 else:
#    1464     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/pt_utils.py:269, in PipelinePackIterator.__next__(self)
#     266             return accumulator
#     268 while not is_last:
# --> 269     processed = self.infer(next(self.iterator), **self.params)
#     270     if self.loader_batch_size is not None:
#     271         if isinstance(processed, torch.Tensor):
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1371, in Pipeline.forward(self, model_inputs, **forward_params)
#    1369     with inference_context():
#    1370         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1371         model_outputs = self._forward(model_inputs, **forward_params)
#    1372         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1373 else:
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/pipelines/zero_shot_classification.py:227, in ZeroShotClassificationPipeline._forward(self, inputs)
#     225 if "use_cache" in inspect.signature(model_forward).parameters.keys():
#     226     model_inputs["use_cache"] = False
# --> 227 outputs = self.model(**model_inputs)
#     229 model_outputs = {
#     230     "candidate_label": candidate_label,
#     231     "sequence": sequence,
#     232     "is_last": inputs["is_last"],
#     233     **outputs,
#     234 }
#     235 return model_outputs
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1641, in BartForSequenceClassification.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1636 if input_ids is None and inputs_embeds is not None:
#    1637     raise NotImplementedError(
#    1638         f"Passing input embeddings is currently not supported for {self.__class__.__name__}"
#    1639     )
# -> 1641 outputs = self.model(
#    1642     input_ids,
#    1643     attention_mask=attention_mask,
#    1644     decoder_input_ids=decoder_input_ids,
#    1645     decoder_attention_mask=decoder_attention_mask,
#    1646     head_mask=head_mask,
#    1647     decoder_head_mask=decoder_head_mask,
#    1648     cross_attn_head_mask=cross_attn_head_mask,
#    1649     encoder_outputs=encoder_outputs,
#    1650     inputs_embeds=inputs_embeds,
#    1651     decoder_inputs_embeds=decoder_inputs_embeds,
#    1652     use_cache=use_cache,
#    1653     output_attentions=output_attentions,
#    1654     output_hidden_states=output_hidden_states,
#    1655     return_dict=return_dict,
#    1656     cache_position=cache_position,
#    1657 )
#    1658 hidden_states = outputs[0]  # last hidden state
#    1660 eos_mask = input_ids.eq(self.config.eos_token_id).to(hidden_states.device)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:1292, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1289 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1291 if encoder_outputs is None:
# -> 1292     encoder_outputs = self.encoder(
#    1293         input_ids=input_ids,
#    1294         attention_mask=attention_mask,
#    1295         head_mask=head_mask,
#    1296         inputs_embeds=inputs_embeds,
#    1297         output_attentions=output_attentions,
#    1298         output_hidden_states=output_hidden_states,
#    1299         return_dict=return_dict,
#    1300     )
#    1301 # If the user passed a tuple for encoder_outputs, we wrap it in a BaseModelOutput when return_dict=True
#    1302 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:879, in BartEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     877     layer_outputs = (None, None)
#     878 else:
# --> 879     layer_outputs = encoder_layer(
#     880         hidden_states,
#     881         attention_mask,
#     882         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#     883         output_attentions=output_attentions,
#     884     )
#     886     hidden_states = layer_outputs[0]
#     888 if output_attentions:
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/modeling_layers.py:83, in GradientCheckpointingLayer.__call__(self, *args, **kwargs)
#      80         logger.warning(message)
#      82     return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 83 return super().__call__(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:313, in BartEncoderLayer.forward(self, hidden_states, attention_mask, layer_head_mask, output_attentions)
#     301 """
#     302 Args:
#     303     hidden_states (`torch.FloatTensor`): input to the layer of shape `(batch, seq_len, embed_dim)`
#    (...)
#     310         returned tensors for more detail.
#     311 """
#     312 residual = hidden_states
# --> 313 hidden_states, attn_weights, _ = self.self_attn(
#     314     hidden_states=hidden_states,
#     315     attention_mask=attention_mask,
#     316     layer_head_mask=layer_head_mask,
#     317     output_attentions=output_attentions,
#     318 )
#     319 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     320 hidden_states = residual + hidden_states
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/transformers/models/bart/modeling_bart.py:269, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions, cache_position, **kwargs)
#     255 attn_output, attn_weights = attention_interface(
#     256     self,
#     257     query_states,
#    (...)
#     265     **kwargs,
#     266 )
#     268 attn_output = attn_output.reshape(bsz, tgt_len, -1).contiguous()
# --> 269 attn_output = self.out_proj(attn_output)
#     271 return attn_output, attn_weights, past_key_value
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/book_recommendation/.venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
for i in tqdm(range(0, 300)):
    sequence = books.loc[books["simple_categories"] == "Nonfiction", "description"].reset_index(drop=True)[i]
    predicted_cats += [generate_prediction(sequence, categories)]
    actual_cats +=["non_fiction"]
